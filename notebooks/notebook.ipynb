# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# 2023-10-10 00:45:48.504251: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-10 00:45:51.412184: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-10 00:45:51.412223: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-10 00:45:51.416057: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-10 00:45:52.454649: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
df = load_iris()

df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/Iris-NN-vs-LR-RF-RedPCA/.venv/lib/python3.10/site-packages/sklearn/utils/_bunch.py:54, in Bunch.__getattr__(self, key)
#      53 try:
# ---> 54     return self[key]
#      55 except KeyError:
#
# File /workspaces/Iris-NN-vs-LR-RF-RedPCA/.venv/lib/python3.10/site-packages/sklearn/utils/_bunch.py:39, in Bunch.__getitem__(self, key)
#      35     warnings.warn(
#      36         self._deprecated_key_to_warnings[key],
#      37         FutureWarning,
#      38     )
# ---> 39 return super().__getitem__(key)
#
# KeyError: 'info'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /workspaces/Iris-NN-vs-LR-RF-RedPCA/notebooks/notebook.ipynb Cell 2 line 3
# ...

# %%
# Neural Network credit to Nihar Gajare: https://gist.github.com/NiharG15/cd8272c9639941cf8f481a7c4478d525

X = df.data
y = df.target.reshape(-1, 1)

encoder = OneHotEncoder(sparse=False)
y_ = encoder.fit_transform(y)

train_X, test_X, train_y, test_y = train_test_split(X, y_, test_size=0.20)

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

model.fit(train_X, train_y, verbose=2, batch_size=5, epochs=200)
results = model.evaluate(test_X, test_y)
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# /workspaces/Iris-NN-vs-LR-RF-RedPCA/.venv/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Neural Network Model Summary:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  fc1 (Dense)                 (None, 10)                50
#
#  fc2 (Dense)                 (None, 10)                110
#
#  output (Dense)              (None, 3)                 33
#
# ...
# Total params: 193 (772.00 Byte)
# Trainable params: 193 (772.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# ...
